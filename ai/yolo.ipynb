# %% [markdown]
# # Finetuning yolov8 on custom dataset

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# /home/ashok/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.2+cu121 CPU (12th Gen Intel Core(TM) i5-12500H)
# Setup complete ✅ (16 CPUs, 3.7 GB RAM, 86.6/1006.9 GB disk)

# %%
# dataset = "/content/drive/MyDrive/Smoker YOLO.v2-70-20-10.yolov8.zip"
# !unzip "/content/drive/MyDrive/Smoker YOLO.v2-70-20-10.yolov8.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/smoke_b438_jpg.rf.5b2f806d5092f1c44dda4fbfc6979dd2.jpg
#  extracting: train/images/smoke_b439_jpg.rf.3ed0d93dfb10b9aba1ddf46dc6a9325a.jpg
#  extracting: train/images/smoke_b43_jpg.rf.1371bb793b82afa24aea6814d7428c8c.jpg
#  extracting: train/images/smoke_b440_jpg.rf.c30b2d22c146bc6556deae47c6f65b8b.jpg
#  extracting: train/images/smoke_b442_jpg.rf.3e24405655fb392a3337024bb3040427.jpg
#  extracting: train/images/smoke_b443_jpg.rf.87ac8bb35ee83f285ba5c6f12a1e9b35.jpg
#  extracting: train/images/smoke_b447_jpg.rf.9c57b02eb255aadc40133e5d0c71d6f7.jpg
#  extracting: train/images/smoke_b448_jpg.rf.20e0ac3201011c1b327a824fbcc4dd53.jpg
#  extracting: train/images/smoke_b44_jpg.rf.9d4b520ccc3ca421dc8121b16c719b82.jpg
#  extracting: train/images/smoke_b450_jpg.rf.59a35b8ee4f54f5247b56864556caeaa.jpg
#  extracting: train/images/smoke_b451_jpg.rf.0c3f06fae80c3c19bd7fb190e2d1c02d.jpg
# ...

# %%
# from ultralytics import YOLO
# !yolo detect train data=/content/drive/MyDrive/data.yaml model=yolov8m.pt epochs=80 imgsz=640 project=/content/drive/MyDrive/yolo_smoking_result

# %%
# !yolo detect predict model = server/best.pt source = "pexels-cottonbro-5320212.mp4" save = True
# Out:
# /home/ashok/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.0.229 🚀 Python-3.10.12 torch-2.1.2+cu121 CPU (12th Gen Intel Core(TM) i5-12500H)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/1216) /home/ashok/BalenAI/ai/pexels-cottonbro-5320212.mp4: 640x384 2 rokoks, 484.3ms
# video 1/1 (2/1216) /home/ashok/BalenAI/ai/pexels-cottonbro-5320212.mp4: 640x384 2 rokoks, 463.2ms
# ...
